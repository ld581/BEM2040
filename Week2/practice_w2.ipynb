# %%
#Importing the library to connect to the database.
import sqlite3
#Creating a connection to the database.
conn = sqlite3.connect('films_subset.db')
#A cursor holds resources for a query. Several cursors can be created for a connection.
cur = conn.cursor()

# %%
# Getting all records in the table called "film"
query = "SELECT * FROM film"
cur.execute(query)
rows = cur.fetchall()

# %%
#for row in rows:
#   print(row)

# %%
# Getting the films from 1940
query = "SELECT * FROM film where film_year_start=1940"
cur.execute(query)
rows = cur.fetchall()

for row in rows:
   print(row)
# Out:
# ('tt0026957', 'Rumbo al Cairo', 1940, None, 'Comedy')
# ('tt0027269', 'Alhambra', 1940, None, None)
# ('tt0027606', 'Fantasia sottomarina', 1940, None, 'Short')
# ('tt0028058', 'Olympic Honeymoon', 1940, None, 'Comedy')
# ('tt0029284', 'My Favorite Wife', 1940, None, 'Comedy')
# ('tt0029387', 'Pensaci Giacomino', 1940, None, 'Drama')
# ('tt0029704', "L'ultima nemica", 1940, None, 'Drama')
# ('tt0029868', "Andy Hardy's Dilemma: A Lesson in Mathematics - And Other Things", 1940, None, 'Short')
# ('tt0029876', 'El fanfarrón: ¡Aquí llegó el valentón!', 1940, None, 'Adventure')
# ('tt0030495', 'Narcisse', 1940, None, None)
# ('tt0031030', 'Bulldog Sees It Through', 1940, None, 'Mystery')
# ('tt0031032', 'All at Sea', 1940, None, 'Comedy')
# ('tt0031050', 'Arditi civili', 1940, None, 'Drama')
# ('tt0031061', 'At the Villa Rose', 1940, None, 'Drama')
# ('tt0031077', 'Band Waggon', 1940, None, 'Comedy')
# ('tt0031084', 'Battement de coeur', 1940, None, 'Comedy')
# ('tt0031136', 'La canción del milagro', 1940, None, 'Drama')
# ('tt0031142', 'Casanova heiratet', 1940, None, None)
# ('tt0031146', 'Centomila dollari', 1940, None, 'Comedy')
# ('tt0031174', 'Confidential Lady', 1940, None, 'Romance')
# ('tt0031191', 'Outside the Three-Mile Limit', 1940, None, 'Crime')
# ('tt0031192', "Crook's Tour", 1940, None, 'Comedy')
# ('tt0031217', "Dead Man's Shoes", 1940, None, 'Drama')
# ('tt0031248', "Dr. O'Dowd", 1940, None, 'Drama')
# ('tt0031271', 'En tiempos de Don Porfirio', 1940, None, 'Comedy')
# ('tt0031272', "An Englishman's Home", 1940, None, 'Drama')
# ('tt0031274', 'Eran tres hermanas', 1940, None, None)
# ('tt0031292', 'Familjen Björck', 1940, None, 'Comedy')
# ('tt0031294', 'Fanfulla da Lodi', 1940, None, None)
# ('tt0031341', 'French Without Tears', 1940, None, 'Comedy')
# ('tt0031348', 'Frontier Vengeance', 1940, None, 'Western')
# ('tt0031354', 'Full Speed Ahead', 1940, None, 'Drama')
# ('tt0031355', 'Földindulás', 1940, None, None)
# ('tt0031356', 'Füszer és csemege', 1940, None, 'Drama')
# ('tt0031359', 'Gaslight', 1940, None, 'Mystery')
# ('tt0031368', 'The Girl Who Forgot', 1940, None, 'Comedy')
# ('tt0031372', 'Giù il sipario', 1940, None, 'Comedy')
# ('tt0031378', 'Golden Gloves', 1940, None, 'Crime')
# ('tt0031384', 'The Good Old Days', 1940, None, 'Comedy')
# ('tt0031394', 'The Green Hornet', 1940, None, 'Adventure')
# ('tt0031410', 'The Heckler', 1940, None, 'Comedy')
# ('tt0031425', "His Brother's Keeper", 1940, None, 'Drama')
# ('tt0031444', 'Hoots Mon', 1940, None, 'Comedy')
# ('tt0031457', 'El huésped del sevillano', 1940, None, 'Drama')
# ('tt0031466', 'I Take This Woman', 1940, None, 'Drama')
# ('tt0031504', 'Jail Birds', 1940, None, 'Comedy')
# ('tt0031518', 'Julieta y Romeo', 1940, None, None)
# ('tt0031522', 'Just William', 1940, None, 'Comedy')
# ('tt0031524', 'Das jüngste Gericht', 1940, None, None)
# ('tt0031541', 'Kontsert na ekrane', 1940, None, 'Music')
# ('tt0031545', 'Il ladro sono io', 1940, None, 'Comedy')
# ('tt0031551', 'Una lampada alla finestra', 1940, None, None)
# ('tt0031560', 'La leggenda azzurra', 1940, None, None)
# ('tt0031568', 'Leyenda rota', 1940, None, 'Comedy')
# ('tt0031584', 'La locura de Don Juan', 1940, None, 'Comedy')
# ('tt0031591', 'Los de abajo', 1940, None, 'Drama')
# ('tt0031609', 'La malquerida', 1940, None, None)
# ('tt0031617', 'The Man from Dakota', 1940, None, 'Drama')
# ('tt0031623', 'Ein Mann auf Abwegen', 1940, None, 'Adventure')
# ('tt0031624', 'Manolenka', 1940, None, 'Drama')
# ('tt0031625', 'Mare', 1940, None, None)
# ('tt0031631', 'Martingala', 1940, None, None)
# ('tt0031636', 'Meet Maxwell Archer', 1940, None, 'Adventure')
# ('tt0031641', 'Mexican Spitfire', 1940, None, 'Comedy')
# ('tt0031644', 'The Middle Watch', 1940, None, 'Comedy')
# ('tt0031660', 'Miseria e nobiltà', 1940, None, None)
# ('tt0031672', 'Motel the Operator', 1940, None, 'Drama')
# ('tt0031682', 'Mrs. Pym of Scotland Yard', 1940, None, 'Crime')
# ('tt0031734', 'Nothing But Pleasure', 1940, None, 'Comedy')
# ('tt0031739', 'A nönek mindig sikerül', 1940, None, None)
# ('tt0031741', 'Odio', 1940, None, 'Drama')
# ('tt0031789', 'Pazza di gioia', 1940, None, 'Comedy')
# ('tt0031791', 'Il peccato di Rogelia Sanchez', 1940, None, 'Drama')
# ('tt0031802', 'Podnyataya tselina', 1940, None, 'Drama')
# ('tt0031818', 'Pour le maillot jaune', 1940, None, 'Romance')
# ('tt0031828', 'The Proud Valley', 1940, None, 'Drama')
# ('tt0031853', 'Return to Yesterday', 1940, None, 'Drama')
# ('tt0031854', 'El rey que rabió', 1940, None, 'Comedy')
# ('tt0031856', 'Ricchezza senza domani', 1940, None, None)
# ('tt0031866', 'Ritorno', 1940, None, 'Romance')
# ('tt0031870', 'Roll Wagons Roll', 1940, None, 'Western')
# ('tt0031878', 'Rose scarlatte', 1940, None, 'Comedy')
# ('tt0031900', 'Scandalo per bene', 1940, None, None)
# ('tt0031912', 'A Segunda Viagem Triunfal', 1940, None, 'Documentary')
# ('tt0031913', 'Sei bambine ed il Perseo', 1940, None, None)
# ('tt0031918', 'Shadowed Eyes', 1940, None, 'Crime')
# ('tt0031920', "She Couldn't Say No", 1940, None, 'Comedy')
# ('tt0031964', 'Spook Sport', 1940, None, 'Animation')
# ('tt0031966', 'Sportowiec mimo woli', 1940, None, 'Comedy')
# ('tt0031967', 'Spy for a Day', 1940, None, 'Comedy')
# ('tt0031976', 'The Stars Look Down', 1940, None, 'Drama')
# ('tt0031994', 'Les surprises de la radio', 1940, None, 'Comedy')
# ('tt0032011', 'Ten Days in Paris', 1940, None, 'Drama')
# ('tt0032052', "Trappola d'amore", 1940, None, None)
# ('tt0032058', "Troppo tardi t'ho conosciuta", 1940, None, 'Romance')
# ('tt0032064', 'Tutto per la donna', 1940, None, None)
# ('tt0032073', 'Gli ultimi della strada', 1940, None, 'Drama')
# ('tt0032090', 'Validità giorni dieci', 1940, None, 'Comedy')
# ('tt0032092', 'Vento di milioni', 1940, None, None)
# ('tt0032119', 'Weißer Flieder', 1940, None, 'Comedy')
# ('tt0032161', 'Zlota maska', 1940, None, 'Drama')
# ('tt0032168', '¡Que viene mi marido!', 1940, None, 'Comedy')
# ('tt0032170', 'Diablillos de arrabal', 1940, None, 'Drama')
# ('tt0032172', 'È sbarcato un marinaio', 1940, None, None)
# ('tt0032176', "'Til We Meet Again", 1940, None, 'Drama')
# ('tt0032177', '...som en tjuv om natten', 1940, None, 'Comedy')
# ('tt0032178', '20 Mule Team', 1940, None, 'Action')
# ('tt0032179', '21 Days', 1940, None, 'Drama')
# ('tt0032180', 'Abbandono', 1940, None, 'Drama')
# ('tt0032181', 'Abe Lincoln in Illinois', 1940, None, 'Biography')
# ('tt0032182', 'Addio, giovinezza!', 1940, None, 'Comedy')
# ('tt0032183', 'Adventure in Diamonds', 1940, None, 'Crime')
# ('tt0032184', 'Adventures of Red Ryder', 1940, None, 'Action')
# ('tt0032185', 'Africa Squeaks', 1940, None, 'Animation')
# ('tt0032186', 'Ahí está el detalle', 1940, None, 'Comedy')
# ('tt0032188', 'La alegría de la huerta', 1940, None, 'Comedy')
# ('tt0032189', "Alfalfa's Double", 1940, None, 'Comedy')
# ('tt0032190', 'Ali-Baba Bound', 1940, None, 'Animation')
# ('tt0032191', 'Alias the Deacon', 1940, None, 'Adventure')
# ('tt0032192', 'Alice in Movieland', 1940, None, 'Drama')
# ('tt0032193', 'All About Hash', 1940, None, 'Comedy')
# ('tt0032194', 'All This, and Heaven Too', 1940, None, 'Drama')
# ('tt0032195', 'Alle man på post', 1940, None, 'Comedy')
# ('tt0032196', 'Alles Schwindel', 1940, None, None)
# ('tt0032197', 'Allá en el Trópico', 1940, None, 'Comedy')
# ('tt0032198', 'Always a Bride', 1940, None, 'Comedy')
# ('tt0032199', 'Am I Guilty?', 1940, None, 'Action')
# ('tt0032200', 'Amami, Alfredo!', 1940, None, 'Drama')
# ('tt0032201', 'Americaner Shadchen', 1940, None, 'Comedy')
# ('tt0032202', 'Amiamoci così', 1940, None, None)
# ('tt0032204', 'Amore di ussaro', 1940, None, None)
# ('tt0032205', 'And One Was Beautiful', 1940, None, 'Drama')
# ('tt0032206', 'Andy Hardy Meets Debutante', 1940, None, 'Comedy')
# ('tt0032207', 'An Angel from Texas', 1940, None, 'Comedy')
# ('tt0032208', 'Angelika', 1940, None, None)
# ('tt0032209', 'Angels Over Broadway', 1940, None, 'Adventure')
# ('tt0032210', 'Anjaam', 1940, None, None)
# ('tt0032211', 'Anne of Windy Poplars', 1940, None, 'Drama')
# ('tt0032212', 'Antonio Meucci', 1940, None, None)
# ('tt0032214', 'Ants in the Plants', 1940, None, 'Animation')
# ('tt0032215', 'The Ape', 1940, None, 'Horror')
# ('tt0032216', 'Mein Kampf - My Crimes', 1940, None, 'Biography')
# ('tt0032217', "L'arcidiavolo", 1940, None, None)
# ('tt0032218', 'Argentine Nights', 1940, None, 'Comedy')
# ('tt0032219', 'Argila', 1940, None, 'Drama')
# ('tt0032220', 'Arise, My Love', 1940, None, 'Comedy')
# ('tt0032221', 'Arizona', 1940, None, 'Action')
# ('tt0032222', 'Arizona Frontier', 1940, None, 'Western')
# ('tt0032223', 'Arizona Gang Busters', 1940, None, 'Western')
# ('tt0032225', "L'assedio dell'Alcazar", 1940, None, 'Drama')
# ('tt0032226', 'Aurat', 1940, None, 'Drama')
# ('tt0032227', 'Aus erster Ehe', 1940, None, None)
# ('tt0032228', 'Osen', 1940, None, 'Short')
# ('tt0032230', 'Babicka', 1940, None, 'Drama')
# ('tt0032231', 'Babies for Sale', 1940, None, 'Crime')
# ('tt0032232', 'Bad Man from Red Butte', 1940, None, 'Action')
# ('tt0032233', 'Bal paré', 1940, None, 'Comedy')
# ('tt0032234', 'The Bank Dick', 1940, None, 'Comedy')
# ('tt0032235', 'Barcelona, ritmo de un día', 1940, None, 'Documentary')
# ('tt0032237', 'Barnet', 1940, None, 'Family')
# ('tt0032238', 'Barnyard Babies', 1940, None, 'Animation')
# ('tt0032239', 'Barnyard Follies', 1940, None, 'Comedy')
# ('tt0032240', 'Bastard', 1940, None, 'Drama')
# ('tt0032242', 'Il bazar delle idee', 1940, None, None)
# ('tt0032243', "The Bear's Tale", 1940, None, 'Animation')
# ('tt0032244', 'Bedtime for Sniffles', 1940, None, 'Animation')
# ('tt0032245', 'Before I Hang', 1940, None, 'Crime')
# ('tt0032246', 'Behind the News', 1940, None, 'Drama')
# ('tt0032247', 'Beyond Tomorrow', 1940, None, 'Drama')
# ('tt0032249', 'The Big Premiere', 1940, None, 'Comedy')
# ('tt0032250', 'Un bigote para dos', 1940, None, 'Comedy')
# ('tt0032251', 'Billposters', 1940, None, 'Animation')
# ('tt0032252', 'A Bill of Divorcement', 1940, None, 'Drama')
# ('tt0032253', 'Billy the Kid in Texas', 1940, None, 'Western')
# ('tt0032254', 'The Biscuit Eater', 1940, None, 'Drama')
# ('tt0032255', 'Bismarck', 1940, None, 'Biography')
# ('tt0032256', 'Bitter Sweet', 1940, None, 'Drama')
# ('tt0032257', 'Black Diamonds', 1940, None, 'Crime')
# ('tt0032258', 'Black Friday', 1940, None, 'Crime')
# ('tt0032259', 'Blazing Six Shooters', 1940, None, 'Western')
# ('tt0032260', 'Den blomstertid...', 1940, None, 'Drama')
# ('tt0032261', 'Blondie Has Servant Trouble', 1940, None, 'Comedy')
# ('tt0032262', 'Blondie Plays Cupid', 1940, None, 'Adventure')
# ('tt0032263', 'Blondie on a Budget', 1940, None, 'Comedy')
# ('tt0032264', 'The Blue Bird', 1940, None, 'Adventure')
# ('tt0032265', 'Blyge Anton', 1940, None, 'Comedy')
# ('tt0032266', 'Boccaccio', 1940, None, 'Comedy')
# ('tt0032267', 'Boda en el pueblo', 1940, None, 'Documentary')
# ('tt0032269', 'Bone Trouble', 1940, None, 'Animation')
# ('tt0032270', 'Boobs in Arms', 1940, None, 'Comedy')
# ('tt0032272', 'The Bookworm Turns', 1940, None, 'Animation')
# ('tt0032273', 'Boom Town', 1940, None, 'Adventure')
# ('tt0032274', 'The Border Legion', 1940, None, 'Western')
# ('tt0032275', 'Boy', 1940, None, 'Adventure')
# ('tt0032276', 'The Boys from Syracuse', 1940, None, 'Comedy')
# ('tt0032277', 'Boys of the City', 1940, None, 'Comedy')
# ('tt0032278', 'Brat geroya', 1940, None, 'Family')
# ('tt0032279', 'The Bride Wore Crutches', 1940, None, 'Action')
# ('tt0032280', 'The Briggs Family', 1940, None, 'Crime')
# ('tt0032281', 'Brigham Young', 1940, None, 'Adventure')
# ('tt0032282', 'Bring Himself Back Alive', 1940, None, 'Animation')
# ('tt0032283', 'British Intelligence', 1940, None, 'Romance')
# ('tt0032284', 'Broadway Melody of 1940', 1940, None, 'Music')
# ('tt0032285', 'Brother Orchid', 1940, None, 'Comedy')
# ('tt0032286', 'Brother Rat and a Baby', 1940, None, 'Comedy')
# ('tt0032287', 'Ett brott', 1940, None, 'Crime')
# ('tt0032288', 'Bubbling Troubles', 1940, None, 'Comedy')
# ('tt0032289', 'Buck Benny Rides Again', 1940, None, 'Comedy')
# ('tt0032292', 'Bullet Code', 1940, None, 'Western')
# ('tt0032293', 'Bullets for Rustlers', 1940, None, 'Action')
# ('tt0032294', 'Busy Bakers', 1940, None, 'Animation')
# ('tt0032295', 'Buyer Beware', 1940, None, 'Crime')
# ('tt0032296', 'Cafe Hostess', 1940, None, 'Crime')
# ('tt0032297', 'Calling All Husbands', 1940, None, 'Comedy')
# ('tt0032298', 'Calling Dr. Porky', 1940, None, 'Animation')
# ('tt0032299', 'Calling Philo Vance', 1940, None, 'Crime')
# ('tt0032300', 'Cantate con me', 1940, None, 'Comedy')
# ('tt0032301', 'La canzone rubata', 1940, None, 'Comedy')
# ('tt0032302', 'Capitan Fracassa', 1940, None, 'Adventure')
# ('tt0032303', 'Il capitano degli ussari', 1940, None, 'Comedy')
# ('tt0032304', 'Captain Caution', 1940, None, 'Action')
# ('tt0032305', 'The Captain Is a Lady', 1940, None, 'Comedy')
# ('tt0032308', 'La carga de los valientes', 1940, None, 'Drama')
# ('tt0032309', 'Carnaval de antaño', 1940, None, 'Comedy')
# ('tt0032311', 'Carolina Moon', 1940, None, 'Action')
# ('tt0032312', 'The Carson City Kid', 1940, None, 'Western')
# ('tt0032313', 'The Case of the Frightened Lady', 1940, None, 'Crime')
# ('tt0032314', 'The House of the Arrow', 1940, None, 'Mystery')
# ('tt0032315', 'Castle on the Hudson', 1940, None, 'Crime')
# ('tt0032316', 'Cat College', 1940, None, 'Documentary')
# ('tt0032317', 'Il cavaliere di Kruja', 1940, None, 'Drama')
# ('tt0032319', 'Ceiling Hero', 1940, None, 'Animation')
# ('tt0032320', "Cento lettere d'amore", 1940, None, None)
# ('tt0032321', 'Chad Hanna', 1940, None, 'Drama')
# ('tt0032322', 'Channel Incident', 1940, None, 'Short')
# ('tt0032323', "Charley's (Big-Hearted) Aunt", 1940, None, 'Comedy')
# ('tt0032324', 'Charlie Chan at the Wax Museum', 1940, None, 'Mystery')
# ('tt0032325', 'Charlie Chan in Panama', 1940, None, 'Adventure')
# ('tt0032326', "Charlie Chan's Murder Cruise", 1940, None, 'Mystery')
# ('tt0032327', 'El charro Negro', 1940, None, 'Adventure')
# ('tt0032328', 'Charter Pilot', 1940, None, 'Adventure')
# ('tt0032329', 'Chasing Trouble', 1940, None, 'Adventure')
# ('tt0032330', 'Cherokee Strip', 1940, None, 'Action')
# ('tt0032331', "The Chewin' Bruin", 1940, None, 'Animation')
# ('tt0032332', 'The Cheyenne Kid', 1940, None, 'Action')
# ('tt0032334', 'The Chinese Bungalow', 1940, None, 'Drama')
# ('tt0032335', 'Chingolo', 1940, None, 'Comedy')
# ('tt0032337', 'Chlen pravitelstva', 1940, None, 'Drama')
# ('tt0032338', 'Christmas in July', 1940, None, 'Comedy')
# ('tt0032340', 'Circus Today', 1940, None, 'Animation')
# ('tt0032342', 'City for Conquest', 1940, None, 'Drama')
# ('tt0032343', 'City of Chance', 1940, None, 'Crime')
# ('tt0032344', 'Claudine', 1940, None, None)
# ('tt0032345', 'Cold Turkey', 1940, None, 'Comedy')
# ('tt0032346', 'Colorado', 1940, None, 'Western')
# ('tt0032347', "Comin' Round the Mountain", 1940, None, 'Comedy')
# ('tt0032348', 'Common Heritage', 1940, None, 'Short')
# ('tt0032349', 'Comrade X', 1940, None, 'Comedy')
# ('tt0032350', 'La comédie du bonheur', 1940, None, 'Comedy')
# ('tt0032351', 'Four Shall Die', 1940, None, 'Crime')
# ('tt0032352', 'Confederate Honey', 1940, None, 'Animation')
# ('tt0032353', 'Congo Maisie', 1940, None, 'Comedy')
# ('tt0032355', 'The Constable', 1940, None, 'Animation')
# ('tt0032356', 'Contraband', 1940, None, 'Crime')
# ('tt0032357', 'Contraste', 1940, None, 'Music')
# ('tt0032358', 'Convicted Woman', 1940, None, 'Action')
# ('tt0032359', 'Convoy', 1940, None, 'Drama')
# ('tt0032361', 'The Courageous Dr. Christian', 1940, None, 'Drama')
# ('tt0032362', 'Covered Wagon Days', 1940, None, 'Western')
# ('tt0032363', 'Covered Wagon Trails', 1940, None, 'Action')
# ('tt0032364', 'The Cowboy from Sundown', 1940, None, 'Western')
# ('tt0032366', 'Crimes at the Dark House', 1940, None, 'Drama')
# ('tt0032367', 'The Crooked Road', 1940, None, 'Drama')
# ('tt0032368', 'Cross Country Detours', 1940, None, 'Animation')
# ('tt0032369', 'Cross-Country Romance', 1940, None, 'Comedy')
# ('tt0032371', 'Cookoo Cavaliers', 1940, None, 'Comedy')
# ('tt0032373', 'Curtain Call', 1940, None, 'Comedy')
# ('tt0032374', 'Córdoba', 1940, None, 'Short')
# ('tt0032375', 'Dad Rudd, M.P.', 1940, None, 'Comedy')
# ('tt0032376', 'Dance, Girl, Dance', 1940, None, 'Comedy')
# ('tt0032377', 'Dancing on a Dime', 1940, None, 'Comedy')
# ('tt0032378', 'The Dandy Lion', 1940, None, 'Animation')
# ('tt0032379', 'Danger Ahead', 1940, None, 'Adventure')
# ('tt0032380', 'Danger on Wheels', 1940, None, 'Sport')
# ('tt0032381', 'Dankó Pista', 1940, None, 'Drama')
# ('tt0032382', 'La danza dei milioni', 1940, None, 'Comedy')
# ('tt0032383', 'Dark Command', 1940, None, 'Adventure')
# ('tt0032384', 'De Mayerling à Sarajevo', 1940, None, 'Drama')
# ('tt0032385', "De la ferraille à l'acier victorieux", 1940, None, None)
# ('tt0032386', 'Deadwood Dick', 1940, None, 'Western')
# ('tt0032390', 'The Devil Bat', 1940, None, 'Horror')
# ('tt0032392', "The Devil's Pipeline", 1940, None, 'Adventure')
# ('tt0032393', 'El diablo oportuno', 1940, None, 'Animation')
# ('tt0032394', 'Diamond Frontier', 1940, None, 'Adventure')
# ('tt0032395', 'Diamond Queen', 1940, None, 'Action')
# ('tt0032396', 'A Dispatch from Reuters', 1940, None, 'Biography')
# ('tt0032397', 'The Doctor Takes a Wife', 1940, None, 'Comedy')
# ('tt0032398', 'Doing Impossikible Stunts', 1940, None, 'Animation')
# ('tt0032399', 'La Dolores', 1940, None, 'Drama')
# ('tt0032400', 'Don Pasquale', 1940, None, 'Drama')
# ('tt0032401', "Donald's Dog Laundry", 1940, None, 'Animation')
# ('tt0032402', "Donald's Vacation", 1940, None, 'Animation')
# ('tt0032403', 'Donauschiffer', 1940, None, 'Adventure')
# ('tt0032404', 'Doomed to Die', 1940, None, 'Crime')
# ('tt0032405', 'A Door Will Open', 1940, None, 'Short')
# ('tt0032406', 'The Door with Seven Locks', 1940, None, 'Drama')
# ('tt0032407', 'Dopo divorzieremo', 1940, None, 'Comedy')
# ('tt0032408', 'Dots', 1940, None, 'Animation')
# ('tt0032409', 'Double Alibi', 1940, None, 'Adventure')
# ('tt0032410', 'Down Argentine Way', 1940, None, 'Comedy')
# ('tt0032411', 'Dr. Christian Meets the Women', 1940, None, 'Drama')
# ('tt0032412', 'Dr. Cyclops', 1940, None, 'Adventure')
# ('tt0032413', "Dr. Ehrlich's Magic Bullet", 1940, None, 'Biography')
# ('tt0032414', 'Dr. Kildare Goes Home', 1940, None, 'Drama')
# ('tt0032415', "Dr. Kildare's Crisis", 1940, None, 'Drama')
# ('tt0032416', "Dr. Kildare's Strange Case", 1940, None, 'Crime')
# ('tt0032417', 'Dreaming Out Loud', 1940, None, 'Comedy')
# ('tt0032420', 'Drums of Fu Manchu', 1940, None, 'Action')
# ('tt0032421', 'Drums of the Desert', 1940, None, 'Adventure')
# ('tt0032422', 'Dulcy', 1940, None, 'Adventure')
# ('tt0032423', 'The Durango Kid', 1940, None, 'Western')
# ('tt0032424', 'The Earl of Chicago', 1940, None, 'Drama')
# ('tt0032425', 'Earl of Puddlestone', 1940, None, 'Comedy')
# ('tt0032426', 'The Early Worm Gets the Bird', 1940, None, 'Animation')
# ('tt0032427', 'Earthbound', 1940, None, 'Fantasy')
# ('tt0032428', 'East Side Kids', 1940, None, 'Comedy')
# ('tt0032429', 'East of the River', 1940, None, 'Crime')
# ('tt0032430', "L'ebbrezza del cielo", 1940, None, None)
# ('tt0032432', 'Edison, the Man', 1940, None, 'Biography')
# ('tt0032433', 'The Egg Collector', 1940, None, 'Animation')
# ('tt0032436', 'Eli Eli', 1940, None, 'Drama')
# ('tt0032438', 'Ellery Queen, Master Detective', 1940, None, 'Adventure')
# ('tt0032439', "Elmer's Candid Camera", 1940, None, 'Animation')
# ('tt0032440', 'Emergency Squad', 1940, None, 'Action')
# ('tt0032441', 'En poder de Barba Azul', 1940, None, None)
# ('tt0032442', 'En, men ett lejon!', 1940, None, 'Comedy')
# ('tt0032443', 'Enemy Agent', 1940, None, 'Adventure')
# ('tt0032444', 'Erdélyi kastély', 1940, None, 'Drama')
# ('tt0032445', 'Ergens in Nederland', 1940, None, 'Romance')
# ('tt0032446', 'Erzsébet királyné', 1940, None, 'Drama')
# ('tt0032447', 'Escape', 1940, None, 'Drama')
# ('tt0032448', 'Escape to Glory', 1940, None, 'Drama')
# ('tt0032449', 'Eyes of the Navy', 1940, None, 'Documentary')
# ('tt0032450', 'Falstaff in Wien', 1940, None, 'Music')
# ('tt0032451', 'Una famiglia impossibile', 1940, None, 'Comedy')
# ('tt0032452', 'Familien Olsen', 1940, None, 'Comedy')
# ('tt0032453', 'El famoso Carballeira', 1940, None, 'Comedy')
# ('tt0032454', 'La fanciulla di Portici', 1940, None, 'Drama')
# ('tt0032455', 'Fantasia', 1940, None, 'Animation')
# ('tt0032456', "The Farmer's Daughter", 1940, None, 'Comedy')
# ('tt0032457', 'The Fatal Hour', 1940, None, 'Crime')
# ('tt0032458', 'Father Is a Prince', 1940, None, 'Comedy')
# ('tt0032460', 'Fazenda Velha', 1940, None, 'Short')
# ('tt0032461', 'Feinde', 1940, None, 'Drama')
# ('tt0032462', 'Feitiço do Império', 1940, None, 'Drama')
# ('tt0032463', 'Females Is Fickle', 1940, None, 'Animation')
# ('tt0032464', 'Feria en Sevilla', 1940, None, 'Documentary')
# ('tt0032465', 'The Fight for Life', 1940, None, 'Drama')
# ('tt0032466', 'Fightin Pals', 1940, None, 'Animation')
# ('tt0032467', 'The Fighting 69th', 1940, None, 'Action')
# ('tt0032468', 'La figlia del corsaro verde', 1940, None, 'Adventure')
# ('tt0032470', 'Fire Chief', 1940, None, 'Animation')
# ('tt0032471', 'The Fishing Bear', 1940, None, 'Animation')
# ('tt0032472', 'Five Little Peppers at Home', 1940, None, 'Drama')
# ('tt0032473', 'Five Little Peppers in Trouble', 1940, None, 'Comedy')
# ('tt0032474', 'The Flag of Humanity', 1940, None, 'Biography')
# ('tt0032475', 'Flash Gordon Conquers the Universe', 1940, None, 'Action')
# ('tt0032476', 'Flight Angels', 1940, None, 'Comedy')
# ('tt0032477', 'Flight Command', 1940, None, 'Drama')
# ('tt0032479', 'Florian', 1940, None, 'Drama')
# ('tt0032480', 'La florista de la reina', 1940, None, None)
# ('tt0032481', 'Flowing Gold', 1940, None, 'Adventure')
# ('tt0032482', 'The Flying Squad', 1940, None, 'Crime')
# ('tt0032483', 'For Freedom', 1940, None, 'Drama')
# ('tt0032484', 'Foreign Correspondent', 1940, None, 'Action')
# ('tt0032485', 'Forgotten Girls', 1940, None, 'Crime')
# ('tt0032486', 'Fortuna', 1940, None, None)
# ('tt0032487', 'Forty Little Mothers', 1940, None, 'Drama')
# ('tt0032489', 'The Fowl Ball Player', 1940, None, 'Animation')
# ('tt0032490', 'Four Sons', 1940, None, 'Drama')
# ('tt0032491', 'Framed', 1940, None, 'Drama')
# ('tt0032492', 'Free, Blonde and 21', 1940, None, 'Drama')
# ('tt0032493', 'Frestelse', 1940, None, 'Drama')
# ('tt0032494', 'Friedrich Schiller - Der Triumph eines Genies', 1940, None, 'Drama')
# ('tt0032495', 'Friendly Neighbors', 1940, None, 'Comedy')
# ('tt0032496', 'From Nurse to Worse', 1940, None, 'Comedy')
# ('tt0032497', 'Frontier Crusader', 1940, None, 'Western')
# ('tt0032498', 'Das Fräulein von Barnhelm', 1940, None, 'Comedy')
# ('tt0032499', 'A Fugitive from Justice', 1940, None, 'Crime')
# ('tt0032500', 'Fugitive from a Prison Camp', 1940, None, 'Drama')
# ('tt0032501', 'The Fulla Bluff Man', 1940, None, 'Animation')
# ('tt0032502', 'Férjet keresek', 1940, None, 'Romance')
# ('tt0032503', 'Gallant Sons', 1940, None, 'Mystery')
# ('tt0032504', "Gallopin' Gals", 1940, None, 'Animation')
# ('tt0032505', 'Gambling on the High Seas', 1940, None, 'Action')
# ('tt0032506', 'La ganadería en la zona sur', 1940, None, 'Documentary')
# ('tt0032507', 'A Gander at Mother Goose', 1940, None, 'Animation')
# ('tt0032508', 'Gang War', 1940, None, 'Crime')
# ('tt0032509', 'Gangs of Chicago', 1940, None, 'Crime')
# ('tt0032510', 'Garrison Follies', 1940, None, 'Comedy')
# ('tt0032513', 'Gaucho Serenade', 1940, None, 'Western')
# ('tt0032514', 'The Gay Caballero', 1940, None, 'Western')
# ('tt0032515', 'Die Geierwally', 1940, None, 'Drama')
# ('tt0032516', 'Gentleman att hyra', 1940, None, 'Comedy')
# ('tt0032517', 'George Washington Carver', 1940, None, 'Biography')
# ('tt0032518', 'George and Margaret', 1940, None, 'Comedy')
# ('tt0032519', 'La gerla di papà Martin', 1940, None, 'Drama')
# ('tt0032520', 'The Ghost Breakers', 1940, None, 'Comedy')
# ('tt0032521', 'The Ghost Comes Home', 1940, None, 'Comedy')
# ('tt0032522', 'Ghost Valley Raiders', 1940, None, 'Action')
# ('tt0032523', 'Ghost Wanted', 1940, None, 'Animation')
# ('tt0032525', 'Girl from Avenue A', 1940, None, 'Comedy')
# ('tt0032526', "Girl from God's Country", 1940, None, 'Drama')
# ('tt0032527', 'Girl from Havana', 1940, None, 'Drama')
# ('tt0032528', 'Girl in 313', 1940, None, 'Crime')
# ('tt0032529', 'Girls Under 21', 1940, None, 'Adventure')
# ('tt0032530', 'Girls of the Road', 1940, None, 'Action')
# ('tt0032531', 'La gitanilla', 1940, None, 'Drama')
# ('tt0032533', 'Give Us Wings', 1940, None, 'Adventure')
# ('tt0032534', 'Glamour for Sale', 1940, None, 'Adventure')
# ('tt0032535', 'Gloria del Moncayo', 1940, None, None)
# ('tt0032536', 'Go West', 1940, None, 'Comedy')
# ('tt0032537', 'Godvakker-Maren', 1940, None, None)
# ('tt0032538', "Goin' Fishin'", 1940, None, 'Comedy')
# ('tt0032539', 'Gold Rush Maisie', 1940, None, 'Comedy')
# ('tt0032540', 'The Golden Trail', 1940, None, 'Music')
# ('tt0032541', 'Golowin geht durch die Stadt', 1940, None, 'Crime')
# ('tt0032542', 'Good Bad Boys', 1940, None, 'Comedy')
# ('tt0032543', 'Good Night Elmer', 1940, None, 'Animation')
# ('tt0032544', "Goofy's Glider", 1940, None, 'Animation')
# ('tt0032545', 'Gracia y justicia', 1940, None, None)
# ('tt0032546', 'Grand Ole Opry', 1940, None, 'Comedy')
# ('tt0032547', 'Grandpa Goes to Town', 1940, None, 'Comedy')
# ('tt0032548', 'La granduchessa si diverte', 1940, None, 'Comedy')
# ('tt0032549', 'Granite Hotel', 1940, None, 'Animation')
# ('tt0032550', 'Granny Get Your Gun', 1940, None, 'Action')
# ('tt0032551', 'The Grapes of Wrath', 1940, None, 'Drama')
# ('tt0032552', 'The Great Advisor', 1940, None, None)
# ('tt0032553', 'The Great Dictator', 1940, None, 'Comedy')
# ('tt0032554', 'The Great McGinty', 1940, None, 'Comedy')
# ('tt0032555', 'The Great Plane Robbery', 1940, None, 'Adventure')
# ('tt0032556', 'The Great Profile', 1940, None, 'Comedy')
# ('tt0032557', 'The Green Archer', 1940, None, 'Action')
# ('tt0032558', 'Green Hell', 1940, None, 'Adventure')
# ('tt0032559', 'The Green Hornet Strikes Again!', 1940, None, 'Action')
# ('tt0032560', 'Guadalupe', 1940, None, 'Documentary')
# ('tt0032561', 'Guiné, Berço do Império', 1940, None, 'Short')
# ('tt0032562', 'Gül Baba', 1940, None, 'Music')
# ('tt0032563', 'Gun Code', 1940, None, 'Western')
# ('tt0032564', 'Guten Tag liebes Glück', 1940, None, None)
# ('tt0032566', 'Half a Sinner', 1940, None, 'Adventure')
# ('tt0032567', 'Hanna i societén', 1940, None, 'Comedy')
# ('tt0032568', 'Hans nåds testamente', 1940, None, 'Comedy')
# ('tt0032569', 'The Hardship of Miles Standish', 1940, None, 'Animation')
# ('tt0032571', "Busman's Honeymoon", 1940, None, 'Comedy')
# ('tt0032572', 'Haunted House', 1940, None, 'Comedy')
# ('tt0032573', 'Hazafelé', 1940, None, None)
# ('tt0032574', 'Hazajáró lélek', 1940, None, 'Drama')
# ('tt0032575', 'He Married His Wife', 1940, None, 'Comedy')
# ('tt0032576', 'He Stayed for Breakfast', 1940, None, 'Comedy')
# ('tt0032577', 'Hebihimesama', 1940, None, 'Drama')
# ('tt0032579', 'Hennes melodi', 1940, None, 'Comedy')
# ('tt0032580', 'Henry Steps Out', 1940, None, 'Comedy')
# ('tt0032581', 'Her First Romance', 1940, None, 'Drama')
# ('tt0032582', 'Her Second Mother', 1940, None, 'Comedy')
# ('tt0032583', 'Herencia macabra', 1940, None, 'Horror')
# ('tt0032584', 'Heroes of the Saddle', 1940, None, 'Sport')
# ('tt0032585', 'Der Herr im Haus', 1940, None, 'Comedy')
# ('tt0032586', 'Herz - modern möbliert', 1940, None, 'Comedy')
# ('tt0032587', 'Das Herz der Königin', 1940, None, 'Biography')
# ('tt0032588', 'Herz ohne Heimat', 1940, None, 'Drama')
# ('tt0032589', 'Herzensfreud - Herzensleid', 1940, None, 'Comedy')
# ('tt0032590', 'Hi-Yo Silver', 1940, None, 'Western')
# ('tt0032591', 'Hidden Enemy', 1940, None, 'Action')
# ('tt0032592', 'Hidden Gold', 1940, None, 'Western')
# ('tt0032594', 'Hierro en Vizcaya', 1940, None, 'Documentary')
# ('tt0032595', 'High School', 1940, None, 'Comedy')
# ('tt0032596', 'Hired Wife', 1940, None, 'Comedy')
# ('tt0032597', 'His Bridal Fright', 1940, None, 'Comedy')
# ('tt0032598', 'His Ex Marks the Spot', 1940, None, 'Comedy')
# ('tt0032599', 'His Girl Friday', 1940, None, 'Comedy')
# ('tt0032600', 'Hit Parade of 1941', 1940, None, 'Comedy')
# ('tt0032601', 'Hjältar i gult och blått', 1940, None, 'Comedy')
# ('tt0032602', 'Hold That Woman!', 1940, None, 'Comedy')
# ('tt0032603', 'Holiday Highlights', 1940, None, 'Animation')
# ('tt0032604', 'Home Movies', 1940, None, 'Comedy')
# ('tt0032605', 'Home on the Range', 1940, None, 'Animation')
# ('tt0032606', 'The Homeless Flea', 1940, None, 'Animation')
# ('tt0032607', 'Honeymoon Deferred', 1940, None, 'Mystery')
# ('tt0032608', 'Hot Steel', 1940, None, 'Drama')
# ('tt0032609', 'The House Across the Bay', 1940, None, 'Crime')
# ('tt0032610', 'The House of the Seven Gables', 1940, None, 'Drama')
# ('tt0032611', 'How High Is Up?', 1940, None, 'Comedy')
# ('tt0032612', 'The Howards of Virginia', 1940, None, 'Drama')
# ('tt0032613', "Hudson's Bay", 1940, None, 'Adventure')
# ('tt0032614', 'Hullabaloo', 1940, None, 'Comedy')
# ('tt0032615', 'Hullo, Fame!', 1940, None, 'Documentary')
# ('tt0032616', "I Can't Give You Anything But Love, Baby", 1940, None, 'Comedy')
# ('tt0032617', 'I Love You Again', 1940, None, 'Comedy')
# ('tt0032618', 'I Take This Oath', 1940, None, 'Crime')
# ('tt0032619', 'I Want a Divorce', 1940, None, 'Comedy')
# ('tt0032620', 'I Was an Adventuress', 1940, None, 'Comedy')
# ('tt0032621', "I'm Nobody's Sweetheart Now", 1940, None, 'Adventure')
# ('tt0032622', "I'm Still Alive", 1940, None, 'Action')
# ('tt0032624', 'If I Had My Way', 1940, None, 'Comedy')
# ('tt0032625', 'Igen vagy nem?', 1940, None, 'Comedy')
# ('tt0032626', 'Ihr Privatsekretär', 1940, None, 'Comedy')
# ('tt0032627', 'Im Schatten des Berges', 1940, None, 'Adventure')
# ('tt0032628', "L'imprevisto", 1940, None, 'Comedy')
# ('tt0032629', 'In Old Missouri', 1940, None, 'Adventure')
# ('tt0032630', 'Incanto di mezzanotte', 1940, None, None)
# ('tt0032632', "L'ispettore Vargas", 1940, None, None)
# ('tt0032633', 'Inspiración', 1940, None, 'Short')
# ('tt0032635', 'The Invisible Man Returns', 1940, None, 'Drama')
# ('tt0032637', 'The Invisible Woman', 1940, None, 'Comedy')
# ('tt0032638', 'Irene', 1940, None, 'Comedy')
# ('tt0032639', 'Isla de Madera', 1940, None, 'Short')
# ('tt0032640', 'Isla de San Miguel', 1940, None, 'Short')
# ('tt0032641', 'Island of Doomed Men', 1940, None, 'Crime')
# ('tt0032642', 'Isle of Destiny', 1940, None, 'Adventure')
# ('tt0032643', 'It All Came True', 1940, None, 'Comedy')
# ('tt0032644', "It's a Date", 1940, None, 'Comedy')
# ('tt0032645', 'Jack Pot', 1940, None, 'Crime')
# ('tt0032646', 'Jai-Alai', 1940, None, None)
# ('tt0032647', 'El jefe máximo', 1940, None, 'Comedy')
# ('tt0032648', 'Jennie', 1940, None, 'Drama')
# ('tt0032649', 'The Jewish Melody', 1940, None, None)
# ('tt0032651', 'Johnny Apollo', 1940, None, 'Crime')
# ('tt0032652', 'João Ratão', 1940, None, 'Drama')
# ('tt0032653', 'Jud Süß', 1940, None, 'Drama')
# ('tt0032654', 'Julio Romero de Torres', 1940, None, 'Documentary')
# ('tt0032655', 'Juninatten', 1940, None, 'Drama')
# ('tt0032656', 'Junior G-Men', 1940, None, 'Action')
# ('tt0032657', 'Jöjjön elsején!', 1940, None, None)
# ('tt0032658', 'Kalyani', 1940, None, 'Drama')
# ('tt0032659', 'Karl för sin hatt', 1940, None, 'Comedy')
# ('tt0032660', 'Karusellen går...', 1940, None, 'Comedy')
# ('tt0032661', 'Kean', 1940, None, 'Drama')
# ('tt0032662', 'Kersantilleko Emma nauroi?', 1940, None, 'Comedy')
# ('tt0032663', 'A Kick in Time', 1940, None, 'Animation')
# ('tt0032664', 'The Kid from Santa Fe', 1940, None, 'Action')
# ('tt0032665', 'Kiddie Kure', 1940, None, 'Comedy')
# ('tt0032667', 'King for a Day', 1940, None, 'Animation')
# ('tt0032668', 'King of the Lumberjacks', 1940, None, 'Action')
# ('tt0032669', 'King of the Royal Mounted', 1940, None, 'Action')
# ('tt0032670', 'Kit Carson', 1940, None, 'Biography')
# ('tt0032671', 'Kitty Foyle', 1940, None, 'Drama')
# ('tt0032672', 'Kleider machen Leute', 1940, None, 'Comedy')
# ('tt0032673', 'Der Kleinstadtpoet', 1940, None, 'Comedy')
# ('tt0032674', 'Knights of the Range', 1940, None, 'Western')
# ('tt0032675', 'Know Your Money', 1940, None, 'Crime')
# ('tt0032676', 'Knute Rockne All American', 1940, None, 'Biography')
# ('tt0032677', 'Kora Terry', 1940, None, 'Drama')
# ('tt0032678', 'Krambambuli', 1940, None, None)
# ('tt0032679', 'Kronans käcka gossar', 1940, None, 'Comedy')
# ('tt0032680', 'Kyss henne!', 1940, None, 'Comedy')
# ('tt0032681', 'Kyökin puolella', 1940, None, 'Comedy')
# ('tt0032682', 'La Conga Nights', 1940, None, 'Comedy')
# ('tt0032683', 'Laddie', 1940, None, 'Drama')
# ('tt0032684', 'Ladies Must Live', 1940, None, 'Comedy')
# ('tt0032686', 'The Lady in Question', 1940, None, 'Comedy')
# ('tt0032687', 'Lady with Red Hair', 1940, None, 'Biography')
# ('tt0032689', 'Land of the Six Guns', 1940, None, 'Action')
# ('tt0032690', 'The Last Alarm', 1940, None, 'Action')
# ('tt0032691', 'Laughing at Danger', 1940, None, 'Comedy')
# ('tt0032692', 'Lauter Liebe', 1940, None, 'Comedy')
# ('tt0032693', 'Law and Disorder', 1940, None, 'Comedy')
# ('tt0032694', 'Law and Order', 1940, None, 'Western')
# ('tt0032695', 'The Leather Pushers', 1940, None, 'Adventure')
# ('tt0032696', 'Legion of the Lawless', 1940, None, 'Western')
# ('tt0032697', 'Das leichte Mädchen', 1940, None, 'Comedy')
# ('tt0032698', 'Leidenschaft', 1940, None, 'Drama')
# ('tt0032699', 'Let George Do It!', 1940, None, 'Comedy')
# ('tt0032701', 'The Letter', 1940, None, 'Crime')
# ('tt0032702', 'Die letzte Runde', 1940, None, 'Drama')
# ('tt0032703', "Li'l Abner", 1940, None, 'Comedy')
# ('tt0032704', 'Der liebe Augustin', 1940, None, None)
# ('tt0032705', 'Liebesschule', 1940, None, None)
# ('tt0032706', 'The Light of Western Stars', 1940, None, 'Action')
# ('tt0032707', 'Lightning Strikes West', 1940, None, 'Action')
# ('tt0032709', 'Lillebror och jag', 1940, None, None)
# ('tt0032710', 'Lillian Russell', 1940, None, 'Biography')
# ('tt0032711', 'Liniya Mannergeyma', 1940, None, 'Documentary')
# ('tt0032712', 'Links der Isar - rechts der Spree', 1940, None, None)
# ('tt0032714', 'A Little Bit of Heaven', 1940, None, 'Music')
# ('tt0032715', 'Little Blabbermouse', 1940, None, 'Animation')
# ('tt0032716', 'Little Lambkin', 1940, None, 'Animation')
# ('tt0032717', 'Little Men', 1940, None, 'Comedy')
# ('tt0032718', 'Little Nellie Kelly', 1940, None, 'Comedy')
# ('tt0032719', 'Little Old New York', 1940, None, 'Biography')
# ('tt0032720', 'Little Orvie', 1940, None, 'Comedy')
# ('tt0032723', 'London Can Take It!', 1940, None, 'Documentary')
# ('tt0032724', 'Lone Star Raiders', 1940, None, 'Western')
# ('tt0032725', 'The Lone Wolf Meets a Lady', 1940, None, 'Comedy')
# ('tt0032726', 'The Lone Wolf Strikes', 1940, None, 'Comedy')
# ('tt0032727', 'The Lonesome Stranger', 1940, None, 'Animation')
# ('tt0032728', 'The Long Voyage Home', 1940, None, 'Drama')
# ('tt0032729', 'Loops', 1940, None, 'Animation')
# ('tt0032730', 'Love Thy Neighbor', 1940, None, 'Comedy')
# ('tt0032731', 'Love, Honor and Oh-Baby!', 1940, None, 'Comedy')
# ('tt0032732', 'Lucky Cisco Kid', 1940, None, 'Western')
# ('tt0032733', 'Lucky Partners', 1940, None, 'Comedy')
# ('tt0032734', 'Lucrezia Borgia', 1940, None, 'Drama')
# ('tt0032735', 'Luna gitana', 1940, None, 'Short')
# ('tt0032736', 'Luz de Levante', 1940, None, 'Documentary')
# ('tt0032739', "Ma! He's Making Eyes at Me", 1940, None, 'Comedy')
# ('tt0032742', 'Maddalena... zero in condotta', 1940, None, 'Comedy')
# ('tt0032743', 'Madla zpívá Evrope', 1940, None, 'Drama')
# ('tt0032744', 'Malibu Beach Party', 1940, None, 'Animation')
# ('tt0032746', 'The Man I Married', 1940, None, 'Drama')
# ('tt0032747', 'The Man Who Talked Too Much', 1940, None, 'Drama')
# ('tt0032748', "The Man Who Wouldn't Talk", 1940, None, 'Crime')
# ('tt0032750', 'The Man from Tumbleweeds', 1940, None, 'Western')
# ('tt0032751', 'Man och kvinna', 1940, None, 'Documentary')
# ('tt0032753', 'The Man with Nine Lives', 1940, None, 'Mystery')
# ('tt0032754', 'Manhattan Heartbeat', 1940, None, 'Drama')
# ('tt0032755', 'Mannen som alla ville mörda', 1940, None, 'Crime')
# ('tt0032756', 'Manon Lescaut', 1940, None, 'Drama')
# ('tt0032757', "Manovre d'amore", 1940, None, None)
# ('tt0032759', 'Margie', 1940, None, 'Comedy')
# ('tt0032760', 'Marianela', 1940, None, 'Drama')
# ('tt0032761', 'The Marines Fly High', 1940, None, 'Action')
# ('tt0032762', 'The Mark of Zorro', 1940, None, 'Action')
# ('tt0032763', 'Marked Men', 1940, None, 'Action')
# ('tt0032764', 'Married and in Love', 1940, None, 'Drama')
# ('tt0032766', 'Maryland', 1940, None, 'Drama')
# ('tt0032768', 'Mauricio o Una víctima del vicio', 1940, None, 'Comedy')
# ('tt0032769', 'Me Feelins Is Hurt', 1940, None, 'Animation')
# ('tt0032770', 'Med dej i mina armar', 1940, None, 'Comedy')
# ('tt0032771', 'Med livet som insats', 1940, None, 'Drama')
# ('tt0032772', 'Meet the Fleet', 1940, None, 'Drama')
# ('tt0032773', 'Meet the Missus', 1940, None, 'Comedy')
# ('tt0032774', 'Meet the Wildcat', 1940, None, 'Mystery')
# ('tt0032775', 'Mein Mann darf es nicht wissen', 1940, None, 'Comedy')
# ('tt0032776', 'Meine Tochter lebt in Wien', 1940, None, 'Comedy')
# ('tt0032777', 'Meine Tochter tut das nicht', 1940, None, 'Comedy')
# ('tt0032778', 'Melodie eterne', 1940, None, 'Drama')
# ('tt0032779', 'Melody Ranch', 1940, None, 'Western')
# ('tt0032780', 'Melody and Moonlight', 1940, None, 'Comedy')
# ('tt0032781', 'Men Against the Sky', 1940, None, 'Action')
# ('tt0032782', 'Men with Steel Faces', 1940, None, 'Adventure')
# ('tt0032783', 'Men Without Souls', 1940, None, 'Action')
# ('tt0032786', 'Mexican Spitfire Out West', 1940, None, 'Comedy')
# ('tt0032788', 'Michael Shayne: Private Detective', 1940, None, 'Comedy')
# ('tt0032789', 'The Midas Touch', 1940, None, 'Drama')
# ('tt0032790', 'Midnight Limited', 1940, None, 'Action')
# ('tt0032791', 'Mighty Hunters', 1940, None, 'Animation')
# ('tt0032793', 'Military Academy', 1940, None, 'Drama')
# ('tt0032794', 'The Milky Way', 1940, None, 'Animation')
# ('tt0032795', 'Millionaire Playboy', 1940, None, 'Comedy')
# ('tt0032796', 'Millionaires in Prison', 1940, None, 'Crime')
# ('tt0032797', 'Mir lönd nüd lugg', 1940, None, 'Comedy')
# ('tt0032798', 'The Miracle of Sound', 1940, None, 'Documentary')
# ('tt0032799', 'Misbehaving Husbands', 1940, None, 'Comedy')
# ('tt0032801', 'Die mißbrauchten Liebesbriefe', 1940, None, 'Drama')
# ('tt0032802', 'Moi universitety', 1940, None, 'Biography')
# ('tt0032803', 'Bokuseki', 1940, None, 'Action')
# ('tt0032804', 'Molly Cures a Cowboy', 1940, None, 'Music')
# ('tt0032805', 'Mommy Loves Puppy', 1940, None, 'Animation')
# ('tt0032806', 'Money and the Woman', 1940, None, 'Crime')
# ('tt0032808', 'El monje loco', 1940, None, 'Horror')
# ('tt0032809', 'Moon Over Burma', 1940, None, 'Adventure')
# ('tt0032811', 'The Mortal Storm', 1940, None, 'Drama')
# ('tt0032812', 'Moya lyubov', 1940, None, 'Comedy')
# ('tt0032814', 'Mr. Duck Steps Out', 1940, None, 'Animation')
# ('tt0032815', 'Mr. Mouse Takes a Trip', 1940, None, 'Action')
# ('tt0032816', 'Mrs. Ladybug', 1940, None, 'Animation')
# ('tt0032818', "The Mummy's Hand", 1940, None, 'Adventure')
# ('tt0032819', 'Murder Over New York', 1940, None, 'Mystery')
# ('tt0032820', 'Murder in the Air', 1940, None, 'Action')
# ('tt0032821', 'Murder on the Yukon', 1940, None, 'Adventure')
# ('tt0032822', 'Miyamoto Musashi - Dai-ichi-bu: Kusawake no hitobito - Dai-ni-bu: Eitatsu no mon', 1940, None, 'Drama')
# ('tt0032823', 'Music in My Heart', 1940, None, 'Music')
# ('tt0032825', 'Muzykalnaya istoriya', 1940, None, 'Comedy')
# ('tt0032826', 'Muñequita', 1940, None, 'Comedy')
# ('tt0032828', 'My Little Chickadee', 1940, None, 'Comedy')
# ('tt0032829', 'My Love Came Back', 1940, None, 'Comedy')
# ('tt0032830', 'My Pop, My Pop', 1940, None, 'Animation')
# ('tt0032831', 'My Son, My Son!', 1940, None, 'Drama')
# ('tt0032832', 'Mysterious Doctor Satan', 1940, None, 'Action')
# ('tt0032833', 'Mystery in Swing', 1940, None, 'Action')
# ('tt0032834', 'Mystery Sea Raider', 1940, None, 'Drama')
# ('tt0032835', 'Nanette', 1940, None, 'Music')
# ('tt0032836', 'Nartaki', 1940, None, 'Drama')
# ('tt0032837', 'La nascita di Salomè', 1940, None, 'Comedy')
# ('tt0032838', 'Neutral Port', 1940, None, 'Action')
# ('tt0032839', 'The New Britain', 1940, None, 'Short')
# ('tt0032840', 'New Moon', 1940, None, 'Adventure')
# ('tt0032841', 'The New Pupil', 1940, None, 'Comedy')
# ('tt0032842', 'Night Train to Munich', 1940, None, 'Thriller')
# ('tt0032843', "A Night at Earl Carroll's", 1940, None, 'Music')
# ('tt0032844', 'Nishizumi senshacho-den', 1940, None, 'War')
# ('tt0032845', 'No Census, No Feeling', 1940, None, 'Comedy')
# ('tt0032846', 'No Time for Comedy', 1940, None, 'Comedy')
# ('tt0032847', 'No, No, Nanette', 1940, None, 'Comedy')
# ('tt0032848', "Nobody's Children", 1940, None, 'Drama')
# ('tt0032849', 'Non me lo dire!', 1940, None, 'Comedy')
# ('tt0032850', 'North West Mounted Police', 1940, None, 'Action')
# ('tt0032851', "'Northwest Passage' (Book I -- Rogers' Rangers)", 1940, None, 'Adventure')
# ('tt0032854', 'Nurse-Mates', 1940, None, 'Animation')
# ('tt0032855', 'Nutty But Nice', 1940, None, 'Comedy')
# ('tt0032856', 'Of Fox and Hounds', 1940, None, 'Animation')
# ('tt0032857', 'Oh, Johnny, How You Can Love!', 1940, None, 'Comedy')
# ('tt0032859', 'Oklahoma Renegades', 1940, None, 'Western')
# ('tt0032862', 'Old Mother Riley in Society', 1940, None, 'Comedy')
# ('tt0032863', 'The Old South', 1940, None, 'Documentary')
# ('tt0032864', "The Old Swimmin' Hole", 1940, None, 'Comedy')
# ('tt0032865', "Oltre l'amore", 1940, None, 'Drama')
# ('tt0032866', 'Los olvidados de Dios', 1940, None, 'Drama')
# ('tt0032867', 'On Their Own', 1940, None, 'Comedy')
# ('tt0032868', 'On the Spot', 1940, None, 'Action')
# ('tt0032869', 'One Crowded Night', 1940, None, 'Drama')
# ('tt0032870', "One Man's Law", 1940, None, 'Western')
# ('tt0032871', 'One Million B.C.', 1940, None, 'Adventure')
# ('tt0032873', 'One Night in the Tropics', 1940, None, 'Comedy')
# ('tt0032874', 'Onion Pacific', 1940, None, 'Animation')
# ('tt0032876', 'Opened by Mistake', 1940, None, 'Comedy')
# ('tt0032877', 'Operette', 1940, None, 'Music')
# ('tt0032879', 'Orphans of the North', 1940, None, 'Action')
# ('tt0032880', 'Osvobozhdeniye', 1940, None, 'Documentary')
# ('tt0032881', 'Our Town', 1940, None, 'Drama')
# ('tt0032882', 'Out West with the Peppers', 1940, None, 'Comedy')
# ('tt0032885', 'Pals of the Silver Sage', 1940, None, 'Western')
# ('tt0032886', 'Pantry Pirate', 1940, None, 'Animation')
# ('tt0032887', 'Papa Gets the Bird', 1940, None, 'Animation')
# ('tt0032889', 'Pardon My Berth Marks', 1940, None, 'Comedy')
# ('tt0032890', 'Parole Fixer', 1940, None, 'Action')
# ('tt0032891', 'Pas på Svinget i Solby', 1940, None, 'Comedy')
# ('tt0032893', 'Passport to Alcatraz', 1940, None, 'Action')
# ('tt0032894', 'Pastor Hall', 1940, None, 'Drama')
# ('tt0032895', 'Patient Porky', 1940, None, 'Animation')
# ('tt0032896', 'La peccatrice', 1940, None, 'Drama')
# ('tt0032897', 'Pedagogical Institution (College to You)', 1940, None, 'Animation')
# ('tt0032898', 'El perro de carreras', 1940, None, 'Animation')
# ('tt0032900', 'Peñíscola, baluarte del Papa Luna', 1940, None, 'Documentary')
# ('tt0032901', 'Phantom Raiders', 1940, None, 'Comedy')
# ('tt0032902', 'Phantom Rancher', 1940, None, 'Western')
# ('tt0032903', 'Phantom of Chinatown', 1940, None, 'Mystery')
# ('tt0032904', 'The Philadelphia Story', 1940, None, 'Comedy')
# ('tt0032905', 'Piccolo alpino', 1940, None, 'Drama')
# ('tt0032907', 'Pico', 1940, None, 'Short')
# ('tt0032908', 'Pier 13', 1940, None, 'Mystery')
# ('tt0032909', 'Pilgrim Porky', 1940, None, 'Animation')
# ('tt0032910', 'Pinocchio', 1940, None, 'Adventure')
# ('tt0032911', 'Pinto Canyon', 1940, None, 'Action')
# ('tt0032912', 'Pioneer Days', 1940, None, 'Western')
# ('tt0032913', 'Pioneers of the Frontier', 1940, None, 'Western')
# ('tt0032914', 'Pioneers of the West', 1940, None, 'Action')
# ('tt0032915', 'Il pirata sono io!', 1940, None, 'Comedy')
# ('tt0032917', 'A Plumbing We Will Go', 1940, None, 'Comedy')
# ('tt0032918', "Pluto's Dream House", 1940, None, 'Animation')
# ('tt0032919', 'Polterabend', 1940, None, 'Comedy')
# ('tt0032920', 'Il ponte dei sospiri', 1940, None, 'Drama')
# ('tt0032921', 'Il ponte di vetro', 1940, None, 'Drama')
# ('tt0032922', 'Pony Express Days', 1940, None, 'Action')
# ('tt0032923', 'Pony Post', 1940, None, 'Western')
# ('tt0032924', 'Poopdeck Pappy', 1940, None, 'Animation')
# ('tt0032925', 'Pop Always Pays', 1940, None, 'Comedy')
# ('tt0032926', 'Popeye Meets William Tell', 1940, None, 'Animation')
# ('tt0032927', 'Popeye Presents Eugene, the Jeep', 1940, None, 'Animation')
# ('tt0032928', 'Popular Science', 1940, None, 'Documentary')
# ('tt0032929', 'Popular Science', 1940, None, 'Documentary')
# ('tt0032930', "Porky's Baseball Broadcast", 1940, None, 'Animation')
# ('tt0032931', "Porky's Hired Hand", 1940, None, 'Animation')
# ('tt0032932', "Porky's Last Stand", 1940, None, 'Animation')
# ('tt0032933', "Porky's Poor Fish", 1940, None, 'Animation')
# ('tt0032934', 'Portugal, Oito Séculos de História', 1940, None, 'Documentary')
# ('tt0032935', 'Der Postmeister', 1940, None, 'Drama')
# ('tt0032936', 'Pound Foolish', 1940, None, 'Crime')
# ('tt0032937', 'Power and the Land', 1940, None, 'Documentary')
# ('tt0032939', 'Prairie Law', 1940, None, 'Western')
# ('tt0032940', 'Prairie Schooners', 1940, None, 'Western')
# ('tt0032941', 'Prehistoric Porky', 1940, None, 'Animation')
# ('tt0032942', 'Prem Nagar', 1940, None, 'Romance')
# ('tt0032943', 'Pride and Prejudice', 1940, None, 'Drama')
# ('tt0032945', 'La prima donna che passa', 1940, None, None)
# ('tt0032946', 'Primrose Path', 1940, None, 'Drama')
# ('tt0032947', 'Private Affairs', 1940, None, 'Comedy')
# ('tt0032949', 'Public Deb No. 1', 1940, None, 'Comedy')
# ('tt0032950', 'Puedes irte de mí', 1940, None, 'Short')
# ('tt0032951', 'Punar Milan', 1940, None, 'Drama')
# ('tt0032952', 'Pureza', 1940, None, 'Drama')
# ('tt0032953', 'Puss Gets the Boot', 1940, None, 'Animation')
# ('tt0032954', 'Put-Put Troubles', 1940, None, 'Animation')
# ('tt0032955', 'Puttin on the Act', 1940, None, 'Animation')
# ('tt0032956', 'Pão Nosso', 1940, None, 'Drama')
# ('tt0032957', 'The Quarterback', 1940, None, 'Comedy')
# ('tt0032958', 'Queen of the Mob', 1940, None, 'Crime')
# ('tt0032959', 'Queen of the Yukon', 1940, None, 'Adventure')
# ('tt0032960', "Quicker'n a Wink", 1940, None, 'Comedy')
# ('tt0032965', 'Ragtime Cowboy Joe', 1940, None, 'Adventure')
# ('tt0032966', 'Rainbow Over the Range', 1940, None, 'Action')
# ('tt0032967', 'A Rainy Day with the Bear Family', 1940, None, 'Animation')
# ('tt0032968', 'The Ramparts We Watch', 1940, None, 'Drama')
# ('tt0032970', 'Rancho Grande', 1940, None, 'Western')
# ('tt0032971', 'The Range Busters', 1940, None, 'Western')
# ('tt0032972', 'The Ranger and the Lady', 1940, None, 'Western')
# ('tt0032973', 'Rangers of Fortune', 1940, None, 'Action')
# ('tt0032976', 'Rebecca', 1940, None, 'Drama')
# ('tt0032977', 'Reflejos de Manises', 1940, None, 'Documentary')
# ('tt0032978', 'La Reggia sul fiume', 1940, None, None)
# ('tt0032980', 'Remedy for Riches', 1940, None, 'Comedy')
# ('tt0032981', 'Remember the Night', 1940, None, 'Comedy')
# ('tt0032982', 'Der rettende Engel', 1940, None, None)
# ('tt0032983', 'The Return of Frank James', 1940, None, 'Adventure')
# ('tt0032984', 'The Return of Wild Bill', 1940, None, 'Western')
# ('tt0032985', 'Rhythm of the Rio Grande', 1940, None, 'Western')
# ('tt0032986', 'Rhythm on the River', 1940, None, 'Comedy')
# ('tt0032987', 'Ride, Tenderfoot, Ride', 1940, None, 'Romance')
# ('tt0032988', 'Riders from Nowhere', 1940, None, 'Action')
# ('tt0032989', 'Riders of Black Mountain', 1940, None, 'Action')
# ('tt0032990', 'Riders of Pasco Basin', 1940, None, 'Action')
# ('tt0032992', 'The Riveter', 1940, None, 'Animation')
# ('tt0032993', 'Road to Singapore', 1940, None, 'Comedy')
# ('tt0032994', 'Ein Robinson', 1940, None, 'Adventure')
# ('tt0032995', "Rockin' Thru the Rockies", 1940, None, 'Comedy')
# ('tt0032996', 'Rocky Mountain Rangers', 1940, None, 'Western')
# ('tt0032997', "Rollin' Home to Texas", 1940, None, 'Action')
# ('tt0032998', 'Romans', 1940, None, 'Drama')
# ('tt0032999', 'Una romantica avventura', 1940, None, 'Drama')
# ('tt0033000', 'Romeo in Rhythm', 1940, None, 'Animation')
# ('tt0033001', 'Room for Two', 1940, None, None)
# ('tt0033002', 'Rosen in Tirol', 1940, None, 'Comedy')
# ('tt0033003', 'Runon kuningas ja muuttolintu', 1940, None, 'Drama')
# ('tt0033006', 'Rózsafabot', 1940, None, 'Drama')
# ('tt0033007', 'SF-paraati', 1940, None, 'Comedy')
# ('tt0033008', 'SOS Doctor Marabú', 1940, None, 'Animation')
# ('tt0033009', 'Safari', 1940, None, 'Adventure')
# ('tt0033010', 'The Sagebrush Family Trails West', 1940, None, 'Action')
# ('tt0033011', "Sailor's Lady", 1940, None, 'Comedy')
# ('tt0033012', "Sailors Don't Care", 1940, None, 'Comedy')
# ('tt0033013', 'The Saint Takes Over', 1940, None, 'Crime')
# ('tt0033014', "The Saint's Double Trouble", 1940, None, 'Action')
# ('tt0033015', 'Salomé', 1940, None, None)
# ('tt0033016', 'Saloon Bar', 1940, None, 'Thriller')
# ('tt0033017', 'San Giovanni decollato', 1940, None, 'Comedy')
# ('tt0033018', 'Sandy Gets Her Man', 1940, None, 'Comedy')
# ('tt0033019', 'Sandy Is a Lady', 1940, None, 'Comedy')
# ...
# ('tt0426153', 'Onna no machi', 1940, None, None)
# ('tt0428830', 'Miyamoto Musashi: Dai-san-bu - Kenshin ichiro', 1940, None, None)
# ('tt0429274', 'Zoku Tsubanari ronin', 1940, None, None)
# ('tt0432020', 'Rembrandt', 1940, None, 'Biography')
# ('tt0434217', 'Das Mädchen von St. Coeur', 1940, None, 'Short')
# ('tt0434245', 'Nyannyan-myao hoi', 1940, None, 'Documentary')
# ('tt0434549', 'Screen Snapshots: Seeing Hollywood', 1940, None, 'Documentary')
# ('tt0434767', 'African Skyway', 1940, None, 'Documentary')
# ('tt0434768', 'Air Communique', 1940, None, 'Documentary')
# ('tt0434769', 'Airscrew', 1940, None, 'Documentary')
# ('tt0435343', 'Ryukyu no fubutsu', 1940, None, 'Documentary')
# ('tt0440956', 'Zoku awa tanuki-gassen', 1940, None, None)
# ('tt0441384', 'Nampû kôkyôkyoku', 1940, None, None)
# ('tt0446094', 'Ecco la felicità', 1940, None, 'Comedy')
# ('tt0448162', 'The Tragedy of Carpatho-Ukraine', 1940, None, 'Documentary')
# ('tt0448606', 'Der liebe Besuch', 1940, None, 'Short')
# ('tt0449631', 'Panama-Pacific International Exhibition', 1940, None, 'News')
# ('tt0450409', 'Dangerous Comment', 1940, None, 'Drama')
# ('tt0450467', "Now You're Talking", 1940, None, 'Drama')
# ('tt0451699', 'Dipak Mahal', 1940, None, 'Action')
# ('tt0451851', 'Pak Daman', 1940, None, None)
# ('tt0455623', "Medicus Film of New York World's Fair", 1940, None, 'Documentary')
# ('tt0457163', 'Tajinko-mura', 1940, None, 'Drama')
# ('tt0457921', 'A Gorodi fogoly', 1940, None, None)
# ('tt0458974', 'Taiheiyô kôshinkyoku', 1940, None, None)
# ('tt0461292', 'Nijisseiki nashi o tsukuru', 1940, None, 'Documentary')
# ('tt0461501', 'Estrellita', 1940, None, None)
# ('tt0461764', 'Dilim at liwanag', 1940, None, None)
# ('tt0461785', 'Huling habilin', 1940, None, 'Drama')
# ('tt0461790', 'Ikaw rin', 1940, None, 'Drama')
# ('tt0462169', 'Aberglaube', 1940, None, 'Short')
# ('tt0463258', 'Ôhinata-mura', 1940, None, None)
# ('tt0464024', 'Glimpses of Washington State', 1940, None, 'Documentary')
# ('tt0467174', 'Dalaga', 1940, None, 'Drama')
# ('tt0467233', 'Senorita', 1940, None, 'Drama')
# ('tt0467713', 'War and Order', 1940, None, 'Short')
# ('tt0469552', 'Sa dating pugad', 1940, None, 'Drama')
# ('tt0471362', 'Rosa birhen', 1940, None, 'Drama')
# ('tt0471374', 'Sawing gantingpala', 1940, None, 'Drama')
# ('tt0471835', 'Neighbours Under Fire', 1940, None, 'Short')
# ('tt0474681', 'Fräulein Huser', 1940, None, 'Drama')
# ('tt0475559', 'Diwa ng awit', 1940, None, 'Drama')
# ('tt0483031', 'Lambingan', 1940, None, 'Drama')
# ('tt0483715', "Let's Get Together", 1940, None, 'Music')
# ('tt0485518', 'Oyako kujira', 1940, None, None)
# ('tt0486437', 'Das neue Asien', 1940, None, None)
# ('tt0487693', "Let's Sing Something", 1940, None, 'Music')
# ('tt0488571', 'Laureate', 1940, None, 'Short')
# ('tt0489975', 'Kinuyo no hatsukoi', 1940, None, None)
# ('tt0490276', 'Butai sugata', 1940, None, None)
# ('tt0490296', 'Okinu to bantô', 1940, None, None)
# ('tt0491028', "Let's Have a Singsong", 1940, None, 'Music')
# ('tt0494025', 'Baumeisterin Chemie', 1940, None, 'Documentary')
# ('tt0495605', "Let's Get Together and Sing", 1940, None, 'Music')
# ('tt0495820', 'Commandment Keeper Church, Beaufort South Carolina, May 1940', 1940, None, 'Documentary')
# ('tt0495892', 'Shall We Sing', 1940, None, 'Music')
# ('tt0495918', 'Young America Flies', 1940, None, 'Adventure')
# ('tt0496923', 'The Alchemist in Hollywood', 1940, None, 'Short')
# ('tt0496948', 'Experiments in the Revival of Organisms', 1940, None, 'Documentary')
# ('tt0497120', "Let's Sing Again", 1940, None, 'Short')
# ('tt0497122', 'Der Marsch zum Führer', 1940, None, 'Documentary')
# ('tt0497129', 'Nikudan chin-yûshi', 1940, None, 'Comedy')
# ('tt0497238', 'Mahal pa rin kita', 1940, None, 'Drama')
# ('tt0497265', 'Santa', 1940, None, None)
# ('tt0498127', 'Something for Nothing', 1940, None, 'Animation')
# ('tt0498486', 'Deutsche Arbeitsstätten', 1940, None, 'Documentary')
# ('tt0498991', 'The Backyard Front', 1940, None, 'Comedy')
# ('tt0764739', 'Dalagang Filipina', 1940, None, 'Drama')
# ('tt0764743', 'Datu-talim', 1940, None, None)
# ('tt0764819', 'Magbalik ka, hirang', 1940, None, 'Drama')
# ('tt0764871', 'Puso ng isang Filipina', 1940, None, None)
# ('tt0764899', 'Tinig ng pag-ibig', 1940, None, None)
# ('tt0777758', 'Bahaghari', 1940, None, None)
# ('tt0777870', 'Gunita', 1940, None, None)
# ('tt0777893', 'Inang pulot', 1940, None, None)
# ('tt0778860', 'Eine Stunde', 1940, None, 'Short')
# ('tt0786933', 'Bawal na pag-ibig', 1940, None, None)
# ('tt0786949', 'Buenavista', 1940, None, None)
# ('tt0786953', 'Cadena de Amor', 1940, None, None)
# ('tt0787012', 'Hali', 1940, None, None)
# ('tt0787017', 'Hatinggabi', 1940, None, None)
# ('tt0787055', 'Kahapon lamang', 1940, None, None)
# ('tt0787079', 'Maginoong takas', 1940, None, 'Comedy')
# ('tt0787096', 'Nagiisang Sangla', 1940, None, 'Drama')
# ('tt0787111', 'Pangarap', 1940, None, None)
# ('tt0787126', 'Prinsesa ng kumintang', 1940, None, 'Drama')
# ('tt0787212', 'Tala sa kabukiran', 1940, None, None)
# ('tt0788018', 'Ave Maria', 1940, None, None)
# ('tt0788055', 'Dating sumpaan', 1940, None, None)
# ('tt0788108', 'Jazmin', 1940, None, None)
# ('tt0788118', 'Lihim ng kapatid', 1940, None, None)
# ('tt0788144', 'Nang mahawi ang ulap', 1940, None, None)
# ('tt0788157', 'Pakiusap', 1940, None, None)
# ('tt0788163', 'Patawad', 1940, None, None)
# ('tt0794385', 'Der Trichter Nr. 10', 1940, None, 'Short')
# ('tt0794389', 'Der Trichter Nr. 8', 1940, None, 'Short')
# ('tt0795979', 'Zoku Shimizu minato', 1940, None, 'Action')
# ('tt0807055', 'Der Trichter Nr. 7', 1940, None, 'Short')
# ('tt0809236', 'She Done Him Right', 1940, None, 'Comedy')
# ('tt0809418', 'O Culpado', 1940, None, 'Drama')
# ('tt0809441', 'O Madeireiro', 1940, None, 'Drama')
# ('tt0809942', 'Santa Rogelia', 1940, None, 'Drama')
# ('tt0844007', 'Hétszilvafa', 1940, None, 'Comedy')
# ('tt0855855', 'Kaigun bakugekitai', 1940, None, 'War')
# ('tt0855881', 'Mohini', 1940, None, None)
# ('tt0887916', 'Ismeretlen ellenfél', 1940, None, None)
# ('tt0891574', 'Pénz beszél', 1940, None, 'Comedy')
# ('tt0892294', 'Fibichuv poem', 1940, None, 'Music')
# ('tt0896786', 'Awit ng magulang', 1940, None, None)
# ('tt0896826', 'Kamoning', 1940, None, None)
# ('tt0896832', 'Magtanim hindi biro', 1940, None, None)
# ('tt0897254', 'Feuertaufe', 1940, None, 'Documentary')
# ('tt0900927', 'Dugo ng alipin', 1940, None, None)
# ('tt0900952', 'Lihim ng lumang simbahan', 1940, None, None)
# ('tt0905617', 'Kampf um Norwegen - Feldzug 1940', 1940, None, 'Documentary')
# ('tt0906062', 'Párbaj semmiért', 1940, None, 'Comedy')
# ('tt0923702', 'Der gestiefelte Kater', 1940, None, 'Animation')
# ('tt0923882', "Ryôgoku no san'nin-musume", 1940, None, None)
# ('tt0948655', 'Kanarienvögel', 1940, None, 'Documentary')
# ('tt0949512', 'Ritorno al vittoriale', 1940, None, 'Documentary')
# ('tt0953425', 'Hatsuharu musume', 1940, None, None)
# ('tt0953488', 'Manzai taxi', 1940, None, None)
# ('tt0953507', 'Musume no haru', 1940, None, None)
# ('tt0953661', 'Yumemiru musume', 1940, None, None)
# ('tt0955242', 'City of Lost Men', 1940, None, 'Sci-Fi')
# ('tt0959357', 'Ungetsu no Suzuran no tsuma', 1940, None, 'Drama')
# ('tt0996622', 'Inseln im Sandmeer', 1940, None, 'Short')
# ('tt1000723', 'Spills for Thrills', 1940, None, 'Action')
# ('tt1008957', 'Screen Snapshots Series 19, No 10', 1940, None, 'Documentary')
# ('tt1008961', 'Screen Snapshots Series 19, No. 7: Wardrobe Designers', 1940, None, 'Documentary')
# ('tt1008962', 'Screen Snapshots Series 19, No. 9: Sports in Hollywood', 1940, None, 'Documentary')
# ('tt1010338', 'Vom Bäumlein, das andere Blätter hat gewollt', 1940, None, 'Animation')
# ('tt1013774', 'Your Town: A Story of America', 1940, None, 'Short')
# ('tt10147806', 'Ina-bushi', 1940, None, 'Drama')
# ('tt1015391', 'Nürnberg, die Stadt der Reichsparteitage', 1940, None, 'Short')
# ('tt10173472', 'Lemmenjoki', 1940, None, 'Documentary')
# ('tt10230664', 'Rahva Tahe', 1940, None, 'Documentary')
# ('tt1024185', 'Eine brasilianische Rhapsodie', 1940, None, 'Short')
# ('tt1024238', 'Die Sommerwiese', 1940, None, 'Short')
# ('tt1033646', 'Wissenschaft weist neue Wege', 1940, None, 'Short')
# ('tt10432842', 'Vanha Viipurimme', 1940, None, 'Documentary')
# ('tt10487702', 'V kukolnoy strane', 1940, None, 'Animation')
# ('tt1051703', 'Calling on Colombia', 1940, None, 'Documentary')
# ('tt1058030', 'Wayda', 1940, None, None)
# ('tt10586542', 'Bits of Our Aircraft Are Missing', 1940, None, 'Short')
# ('tt1071276', 'Cariñosa', 1940, None, 'Drama')
# ('tt1094273', "Shitamachi san'nin musume", 1940, None, 'Drama')
# ('tt1094274', 'Siberia Okiku', 1940, None, 'Drama')
# ('tt10955996', 'Tsuma no sugaô', 1940, None, 'Drama')
# ('tt10995398', 'Fûun byakkojô', 1940, None, 'Drama')
# ('tt10995476', 'Hoka', 1940, None, 'Drama')
# ('tt10996650', 'Aranami bushido', 1940, None, 'Drama')
# ('tt10996828', 'Rainjin takara gassen', 1940, None, 'Drama')
# ('tt10997132', 'Utamatsuri kenka tobi', 1940, None, 'Drama')
# ('tt10997384', 'Gentaro bofû', 1940, None, 'Drama')
# ('tt10997562', 'Yajikita kiso dochu: zenpen', 1940, None, 'Drama')
# ('tt10997790', 'Yajikita kiso dochu: kôhen', 1940, None, 'Drama')
# ('tt10997914', 'Ôgon hebi', 1940, None, 'Drama')
# ('tt11006960', 'Genkosu suikoden', 1940, None, 'Drama')
# ('tt11012292', 'Hoshû', 1940, None, 'Drama')
# ('tt11012360', 'Hakuro kishi', 1940, None, 'Drama')
# ('tt11087660', 'Budô taiheiki', 1940, None, 'Drama')
# ('tt11088026', 'Heiba buyuden', 1940, None, 'Drama')
# ('tt11088350', 'Hitotachi senryo', 1940, None, 'Drama')
# ('tt11101564', 'Jimmy Dorsey and His Orchestra', 1940, None, 'Music')
# ('tt11101748', 'Johnny Messner and His Orchestra', 1940, None, 'Music')
# ('tt11157860', 'Höchstes Glück der Erde auf dem Rücken der Pferde', 1940, None, 'Documentary')
# ('tt11157876', "L'Art Equestre Éternel", 1940, None, 'Documentary')
# ('tt11158330', 'Hochalm', 1940, None, 'Documentary')
# ('tt11158386', 'Bergbauern', 1940, None, 'Documentary')
# ('tt11158418', 'Laufen', 1940, None, 'Documentary')
# ('tt11158428', 'Der Sprung', 1940, None, 'Documentary')
# ('tt1117525', 'Levensvreugde', 1940, None, 'Documentary')
# ('tt11214466', 'Muuten on muistettava..', 1940, None, 'Short')
# ('tt11280830', 'Tessen manyuki', 1940, None, 'Drama')
# ('tt11282770', 'The Green Archer', 1940, None, 'Action')
# ('tt11311372', 'Citizen Kane Trailer', 1940, None, 'Documentary')
# ('tt11424832', 'Shura hakko zenpen', 1940, None, 'Drama')
# ('tt11427882', 'Shura hakko kohen', 1940, None, 'Drama')
# ('tt1144461', 'Acquitted by the Sea', 1940, None, 'Short')
# ('tt1147473', 'The Archives', 1940, None, 'Documentary')
# ('tt1147476', 'Argentina', 1940, None, 'Documentary')
# ('tt11506826', 'Shinpen jako neko daipen jigoku no mon', 1940, None, 'Drama')
# ('tt1155631', 'Romance in Rhythm', 1940, None, 'Music')
# ('tt1155634', "Columbia Panoramics: Tomorrow's Stars", 1940, None, 'Short')
# ('tt1155662', 'Two of a Kind', 1940, None, 'Documentary')
# ('tt1155668', 'Information Please: Series 1, No. 9', 1940, None, 'Short')
# ('tt1155713', 'Not So Dumb', 1940, None, 'Short')
# ('tt1155718', 'Pennant Chasers', 1940, None, 'Short')
# ('tt11605124', 'Fuun shogidani zenpen', 1940, None, 'Drama')
# ('tt11605128', 'Fuun shogidani gohen', 1940, None, 'Drama')
# ('tt1162031', 'Hebihime kyôran', 1940, None, 'Drama')
# ('tt1162043', 'Kaibyô abura jigoku', 1940, None, 'Drama')
# ('tt1162097', 'Onshû hanayome-gitsune', 1940, None, 'Drama')
# ('tt1164637', 'Rekishi: Dai ichi-bu - Dôran boshin', 1940, None, None)
# ('tt1164638', 'Rekishi: Dai ni-bu - Shôdo kensetsu; Dai san-bu: Reimei Nippon', 1940, None, None)
# ('tt1167431', 'Beautiful Bali', 1940, None, 'Documentary')
# ('tt1167432', 'Beautiful British Columbia', 1940, None, 'Documentary')
# ('tt1168755', 'Shônen Noguchi Hideyo', 1940, None, 'Drama')
# ('tt11692348', 'Mobilisatieklanken', 1940, None, 'Music')
# ('tt1172217', 'Tsuchigumo tôge', 1940, None, 'Drama')
# ('tt1172226', 'Yamabuki neko', 1940, None, None)
# ('tt11748392', 'Shogan senbazuru zengohen', 1940, None, 'Drama')
# ('tt1175207', 'Kaiki warau neko', 1940, None, 'Drama')
# ('tt1175244', 'Reimei no ezochi', 1940, None, 'Drama')
# ('tt1177166', 'Ostraum - Deutscher Raum', 1940, None, 'Documentary')
# ('tt11777492', 'Maboroshi-jo daisanbu', 1940, None, None)
# ('tt11777494', 'Maboroshi-jo dainibu', 1940, None, None)
# ('tt1182608', 'The Dipsy Doodler', 1940, None, 'Music')
# ('tt11910530', 'Hua kui nu', 1940, None, None)
# ('tt11980074', 'Perekhod', 1940, None, 'Drama')
# ('tt1199710', 'Tekketsu rônin-gai', 1940, None, 'Drama')
# ('tt1204437', "Suva: 'Pride of Fiji'", 1940, None, 'Documentary')
# ('tt12065216', 'La canción del regreso', 1940, None, 'Romance')
# ('tt12066432', 'Attenzione!', 1940, None, 'Drama')
# ('tt1207782', 'Ungetsu no Kudan no haha', 1940, None, None)
# ('tt12084042', 'Der achti Schwyzer', 1940, None, 'Comedy')
# ('tt1209409', 'Karlsbader Reise. Im Volkswagen auf Goethes Spuren von Weimar nach Karlsbad', 1940, None, 'Short')
# ('tt12104418', 'Nebesa', 1940, None, 'Comedy')
# ('tt1221950', 'Screen Snapshots Series 20, No. 1', 1940, None, 'Short')
# ('tt12243676', 'Beroemde vrouwen', 1940, None, 'Comedy')
# ('tt12258272', 'Qin Liang Yu', 1940, None, 'Drama')
# ('tt1225847', 'Nonki megane', 1940, None, None)
# ('tt12262034', 'Tsena zhizni', 1940, None, 'Drama')
# ('tt1228689', 'Gekiryû', 1940, None, 'Short')
# ('tt1229007', 'Sugino heisôchô no tsuma', 1940, None, 'Drama')
# ('tt12302632', 'How the Ear Functions', 1940, None, 'Documentary')
# ('tt1233423', 'Zoku Hebihimesama', 1940, None, 'Drama')
# ('tt1234940', 'Musume tazunete sanzen-ri', 1940, None, None)
# ('tt12478046', 'Evolution of the World', 1940, None, 'Action')
# ('tt12510770', 'Through the Centre: The Great Red Heart of Australia!', 1940, None, 'Adventure')
# ('tt12518462', "Six semaines d'histoire mondiale", 1940, None, 'Documentary')
# ('tt12518526', 'Kinder, wie die Zeit vergeht', 1940, None, 'History')
# ('tt12572830', 'Pan Qiao Yun', 1940, None, 'Drama')
# ('tt12594952', 'Religion and the People', 1940, None, 'Documentary')
# ('tt1265072', 'Dienst am Kunden', 1940, None, 'Comedy')
# ('tt12655506', 'The Fishing Bear', 1940, None, 'Animation')
# ('tt1265987', 'Das Orchestrion', 1940, None, 'Short')
# ('tt12690504', 'Angels of Mercy', 1940, None, 'Short')
# ('tt12752920', 'Rocco Blues', 1940, None, 'Music')
# ('tt12755538', 'Shoot to Kill', 1940, None, 'Documentary')
# ('tt12916232', 'Did You Know That? Fifth Edition', 1940, None, 'Documentary')
# ('tt12917290', 'Flashing Blades', 1940, None, 'Documentary')
# ('tt12944428', 'Skiways', 1940, None, 'Documentary')
# ('tt12945314', 'Serves You Right!', 1940, None, 'Short')
# ('tt12956484', 'A Certain Nobleman', 1940, None, 'Drama')
# ('tt1308946', 'Ginyoku no otome', 1940, None, None)
# ('tt1308948', 'Haru yo izuko', 1940, None, None)
# ('tt1308961', 'Kingorô no Aa mujô', 1940, None, None)
# ('tt1315357', 'Deutsche Frontflugzeuge', 1940, None, 'Documentary')
# ('tt13223370', 'Horrors of War', 1940, None, 'Documentary')
# ('tt1322915', 'Fashion Forecast No. 6', 1940, None, 'Short')
# ('tt1325564', 'Gonza to Sukejû', 1940, None, None)
# ('tt13290542', 'Prání k Novému roku', 1940, None, 'Animation')
# ('tt13376514', 'Prison Bars Beckon', 1940, None, 'Action')
# ('tt13376518', "The Devil's Dictograph", 1940, None, 'Action')
# ('tt13376520', 'The Face at the Window', 1940, None, 'Action')
# ('tt13376524', 'Vanishing Jewels', 1940, None, 'Action')
# ('tt13376526', 'The Fatal Spark', 1940, None, 'Action')
# ('tt13376528', 'The Necklace of Treachery', 1940, None, 'Action')
# ('tt13376530', 'The Secret Passage', 1940, None, 'Action')
# ('tt13376532', 'Garr Castle is Robbed', 1940, None, 'Action')
# ('tt13376536', 'Mirror of Treachery', 1940, None, 'Action')
# ('tt13376538', 'The Dagger that Failed', 1940, None, 'Action')
# ('tt13376540', 'The Flaming Arrow', 1940, None, 'Action')
# ('tt13376542', 'The Devil Dogs', 1940, None, 'Action')
# ('tt13376544', 'The Deceiving Microphone', 1940, None, 'Action')
# ('tt13376546', 'End of Hope', 1940, None, 'Action')
# ('tt13376548', 'The Green Archer Exposed', 1940, None, 'Action')
# ('tt13386366', 'La caza del puma', 1940, None, 'Animation')
# ('tt1341199', 'Kedok ketawa', 1940, None, 'Drama')
# ('tt13545878', 'Goebbels-Geburtstagsfilm - 29.10.1940', 1940, None, 'Short')
# ('tt1362551', 'Look to Lockheed for Leadership', 1940, None, 'Documentary')

# %%
#Getting all the records in the table called "actor"
query = "SELECT * FROM actor"
cur.execute(query)
rows = cur.fetchall()

for row in rows:
   print(row)

# %%
query = "insert into actor(  actor_id, actor_name, actor_year_born, actor_year_dead) values (?,?,?,?)"

cur.execute(query, ("a1", "Timothée Chalamet", 1994, None))

cur.execute(query, ("a2", "Rebecca Ferguson", 1983, None))

conn.commit()

# %%
#Listing all records after having added two.
query = "SELECT * FROM actor"
cur.execute(query)
rows = cur.fetchall()
for row in rows:
   print(row)
# Out:
# ('a1', 'Timothée Chalamet', 1994, None)
# ('a2', 'Rebecca Ferguson', 1983, None)

# %%
# Updating the birth year of actor with code "a1", that is, Timothée Chalamet
query = "update actor set actor_year_born = ? where actor_id = ?"

cur.execute(query, (1995, "a1"))
conn.commit()

# %%
#Listing actors after the update.
query = "SELECT * FROM actor"
cur.execute(query)
rows = cur.fetchall()
for row in rows:
   print(row)
# Out:
# ('a1', 'Timothée Chalamet', 1995, None)
# ('a2', 'Rebecca Ferguson', 1983, None)

# %%
#Counting the number of records in table actor.

query = "SELECT count(*) FROM actor"
cur.execute(query)
rows = cur.fetchall()
print(rows)
print(rows[0][0])
# Out:
# [(2,)]
# 2

# %%
#Closing the connection
conn.close()
